# %%
import warnings
warnings.filterwarnings('ignore')
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import time
import os
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset,DataLoader

# %%
#check gpu device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#device = torch.device('cpu')

# %%
# load data
dir = 'E:\\Sebnewrepo/Rec_sys_lab/paper1_experiment/'
checkin_file = 'ny_ordered.csv'
df = pd.read_csv(dir + checkin_file)
df.head()
# Out:
#    user_id                    poi_id           poi_category_id  \
# 0        1  4abc1f51f964a520798620e3  4bf58dd8d48988d1ce941735
# 1        1  4d4ac10da0ef54814b6ffff6  4bf58dd8d48988d157941735
# 2        1  4db44994cda1c57c82583709  4bf58dd8d48988d1f1931735
# 3        1  4a541923f964a52008b31fe3  4bf58dd8d48988d14e941735
# 4        1  40f1d480f964a5205b0a1fe3  4bf58dd8d48988d143941735
#
#        poi_category_name   latitude  longitude  time_offset  \
# 0     Seafood Restaurant  40.781558 -73.975792         -240
# 1    American Restaurant  40.784018 -73.974524         -240
# 2  General Entertainment  40.739398 -73.993210         -240
# 3    American Restaurant  40.785677 -73.976498         -240
# 4         Breakfast Spot  40.719929 -74.008532         -240
#
#                          UTC_time             datetime
# 0  Wed Apr 04 23:31:31 +0000 2012  2012-04-04 23:31:31
# 1  Sat Apr 07 17:42:24 +0000 2012  2012-04-07 17:42:24
# 2  Sun Apr 08 18:20:29 +0000 2012  2012-04-08 18:20:29
# 3  Sun Apr 08 20:02:10 +0000 2012  2012-04-08 20:02:10
# 4  Mon Apr 09 16:20:52 +0000 2012  2012-04-09 16:20:52

# %%
# POIs encode, and generate encode mapping
poi_cat = pd.Categorical(df['poi_id'])
poi_encode = poi_cat.codes
#generate poi mapping table
poi_mapping = pd.DataFrame({
    'poi_encode': poi_encode,
    'poi_id': df['poi_id']
    })
#drop duplicate
poi_mapping_output = poi_mapping.drop_duplicates()
df['poi_encode'] = poi_encode
df.drop(['poi_id'], axis = 1, inplace = True)
df.head(5)
# Out:
#    user_id           poi_category_id      poi_category_name   latitude  \
# 0        1  4bf58dd8d48988d1ce941735     Seafood Restaurant  40.781558
# 1        1  4bf58dd8d48988d157941735    American Restaurant  40.784018
# 2        1  4bf58dd8d48988d1f1931735  General Entertainment  40.739398
# 3        1  4bf58dd8d48988d14e941735    American Restaurant  40.785677
# 4        1  4bf58dd8d48988d143941735         Breakfast Spot  40.719929
#
#    longitude  time_offset                        UTC_time  \
# 0 -73.975792         -240  Wed Apr 04 23:31:31 +0000 2012
# 1 -73.974524         -240  Sat Apr 07 17:42:24 +0000 2012
# 2 -73.993210         -240  Sun Apr 08 18:20:29 +0000 2012
# 3 -73.976498         -240  Sun Apr 08 20:02:10 +0000 2012
# 4 -74.008532         -240  Mon Apr 09 16:20:52 +0000 2012
#
#               datetime  poi_encode
# 0  2012-04-04 23:31:31        2752
# 1  2012-04-07 17:42:24        7093
# 2  2012-04-08 18:20:29        7455
# 3  2012-04-08 20:02:10        1958
# 4  2012-04-09 16:20:52         499

# %%
# only keep user id and sequential POIs

df_input = pd.DataFrame({
    'user_id': df['user_id'],  # user_id offset by 1
    'poi_id': df['poi_encode'],
    #'implicit': np.ones(179468)
})

# %%
df_input = df_input.reset_index(drop = True)
df_input
# Out:
#         user_id  poi_id
# 0             1    2752
# 1             1    7093
# 2             1    7455
# 3             1    1958
# 4             1     499
# ...         ...     ...
# 179463     1083    1541
# 179464     1083     466
# 179465     1083    8703
# 179466     1083    9987
# 179467     1083    1956
#
# [179468 rows x 2 columns]

# %%
df_input['user_id'].nunique()
# Out:
# 1083

# %%
df_input['poi_id'].nunique()
# Out:
# 9989

# %%
from copy import deepcopy 
def convert_data(data):
    df = deepcopy(data)
    data = df.groupby('user_id')['poi_id'].apply(list)
    unique_data = df.groupby('user_id')['poi_id'].nunique()
    print(data[:10])
    print(len(data))
    return data

# %%
seq_data = convert_data(df_input)
# Out:
# user_id
# 1     [2752, 7093, 7455, 1958, 499, 270, 9066, 1344,...
# 2     [8834, 1303, 1714, 7089, 4713, 1830, 4512, 192...
# 3     [8246, 1361, 478, 9312, 816, 1028, 6685, 1194,...
# 4     [3662, 3662, 3662, 3662, 3662, 8135, 3662, 298...
# 5     [2000, 2000, 5223, 9244, 2328, 9244, 5223, 924...
# 6     [8584, 9680, 8584, 6217, 2943, 6362, 8584, 376...
# 7     [2854, 6659, 6659, 8077, 2768, 2096, 2411, 721...
# 8     [2946, 2946, 2946, 2179, 2946, 2946, 2946, 294...
# 9     [6942, 3547, 672, 1410, 6942, 2316, 6250, 860,...
# 10    [7183, 532, 532, 1893, 928, 1233, 6883, 5607, ...
# Name: poi_id, dtype: object
# 1083

# %% [markdown]
# ### deal with the POI candidate

# %%
candidate = pd.read_csv('E:/Sebnewrepo/Data/paper1_data/ny_candidate.csv')

# %%
candidate = candidate.merge(poi_mapping_output, on = 'poi_id', how = 'left')
candidate.drop(['poi_id'], axis = 1, inplace = True)
candidate.head()
# Out:
#    Unnamed: 0  user_id    rank  distance  poi_encode
# 0           0        1  7388.0    12.072          33
# 1           1        1  7580.0    11.800          48
# 2           2        1  4849.0    14.673          58
# 3           3        1  5851.0    11.767          64
# 4           4        1  6475.0    11.059          72

# %%
# filter by the distance
candidate = candidate[candidate['distance'] < 15]
candidate.drop(['Unnamed: 0'], axis = 1, inplace = True)
candidate.shape
# Out:
# (6951378, 4)

# %% [markdown]
# ### Select top % candidate
# Top % candidate is the parameters here

# %%
candidate['filtered_rank'] = candidate.groupby('user_id')['rank'].rank()
max_rank = candidate.groupby('user_id')['filtered_rank'].max()
max_rank = max_rank.reset_index()
candidate = candidate.merge(max_rank, on = 'user_id', how = 'left')

# %%
# filter the top 95% candidates
top_ratio = 0.95
candidate = candidate[candidate["filtered_rank_x"] > candidate["filtered_rank_y"]* top_ratio]
candidate.shape
# Out:
# (348068, 6)

# %%
candidate_reduction = pd.DataFrame({
    'user_id': candidate['user_id'],  # user_id offset by 1
    'poi_id': candidate['poi_encode'],
    #'implicit': np.ones(179468)
})
candidate_reduction.head()
# Out:
#       user_id  poi_id
# 582         1    5700
# 595         1    5952
# 765         1    8007
# 769         1    8054
# 6328        8    5952

# %%
candidate_seq = convert_data(candidate_reduction)
candidate_seq = candidate_seq.tolist()
# Out:
# user_id
# 1     [5700, 5952, 8007, 8054, 7590, 4617, 9122, 111...
# 2     [3532, 4327, 5807, 7010, 9661, 6177, 9273, 770...
# 3     [1116, 1941, 3338, 4336, 4983, 7596, 4084, 505...
# 4     [137, 437, 1446, 1604, 2479, 2891, 3282, 3800,...
# 5     [6011, 535, 2730, 2965, 3318, 3410, 3532, 3786...
# 6     [4084, 5055, 6125, 9814, 4140, 5741, 6948, 932...
# 7     [981, 3575, 4657, 7043, 7414, 7648, 9122, 1116...
# 8     [5952, 735, 3348, 3529, 4051, 4617, 4819, 5784...
# 9     [8007, 7043, 1116, 1941, 3338, 4336, 4983, 759...
# 10    [1116, 1941, 3338, 4336, 4983, 7596, 7994, 903...
# Name: poi_id, dtype: object
# 1083

# %% [markdown]
# ### model and evaluation

# %%
class selfAtt(nn.Module):
    def __init__(self, num_user, num_item, model_args, device):
        
        super(selfAtt, self).__init__()
        
        self.args = model_args
        # init args
        self.embedding_dim = self.args.d
        embedding_dim = self.embedding_dim
        self.L = self.args.L  # sequence length
        L = self.L
        self.w = 0.15  # learnable para
        
        # define embedding
        
        self.user_embed = nn.Embedding(num_user, embedding_dim).to(device)
        self.item_embed = nn.Embedding(num_item, embedding_dim).to(device)
        self.item_embed_short = nn.Embedding(num_item, embedding_dim).to(device)
        self.item_embed_long = nn.Embedding(num_item, embedding_dim).to(device)
        self.linear1 = nn.Linear(embedding_dim, embedding_dim).to(device)
        #print(self.linear1)
        self.item_position_embed = nn.Embedding.from_pretrained(self.position_embed(L),freeze=True)
        
        # initialize
        self.user_embed.weight.data.normal_(0, 1.0/self.user_embed.embedding_dim)
        self.item_embed.weight.data.normal_(0, 1.0/self.item_embed.embedding_dim)
        self.linear1.weight.data.normal_(mean=0, std=np.sqrt(2.0 / embedding_dim))
    
    def position_embed(self, L):
        position_embedding = np.array([[pos/np.power(1000, 2.*i)/ self.embedding_dim for i in range(self.embedding_dim)]
                                      for pos in range(L)])
        position_embedding[:,0::2] = np.sin(position_embedding[:,0::2])
        position_embedding[:,1::2] = np.cos(position_embedding[:,1::2])
        t = torch.from_numpy(position_embedding).to(device)
        return t
    
    def forward(self, seq_item, user_id, target, for_pred = False):
        
        '''
        user_id
        seq_item = L item id that user interact before
        target: item target
        '''
        
        # sequential item embedding
        # seq_item = seq_item.to(device)
        item_embedding = self.item_embed(seq_item).to(device)
        # item position embedding
        position_idx = torch.range(0, self.L - 1).unsqueeze(0).expand(seq_item.size(0), -1).long().to(device)
        position_embedding = self.item_position_embed(position_idx)
        item_embedding_cat = item_embedding.float() + position_embedding.float()
        
        # self-attention network
        Q = F.relu(self.linear1(item_embedding_cat))
        K = F.relu(self.linear1(item_embedding_cat))
        #print(K.shape)
        d = torch.FloatTensor([self.embedding_dim]).to(device)
        affinity = torch.matmul(Q, torch.transpose(K, 1, 2))/torch.sqrt(d)
        
        # mask the diagonal value
        mask = torch.eye(item_embedding_cat.size(1), item_embedding_cat.size(1)).byte().to(device)
        affinity = affinity.masked_fill(mask, 0)
        #S = F.softmax(affinity)
        S = torch.sigmoid(affinity)
        #print('s', S.shape)
        attention = torch.mean(torch.matmul(S, item_embedding_cat), dim=1)
        
        # user embedding
        user_id = user_id.to(device)
        user_embedding = self.user_embed(user_id).squeeze()
        #print('user_embed', user_embedding.shape)
        # target embedding short and long note: those two embedding is different 
        
        if target is None:
            target = torch.range(0,self.num_item-1).long().unsqueeze(0).cuda()
            target_embedding_short = self.item_embed_short(target).squeeze()
            target_embedding_long = self.item_embed_long(target).squeeze()
        else:
            target_embedding_short = self.item_embed_short(target).squeeze()
            target_embedding_long = self.item_embed_long(target).squeeze()
        
        # pred
        if for_pred == False:
            user_embedding = user_embedding.unsqueeze(1).expand(-1,target.size(1),-1)
            #print('to train', user_embedding.shape)
            #print('attention before', attention.shape)
            attention = attention.unsqueeze(1).expand(-1,target.size(1),-1)
            #print('attention', attention.shape)
            y_pred = self.w* torch.sqrt(torch.sum((user_embedding - target_embedding_long)**2, dim=2)) + (1-self.w)*torch.sqrt(torch.sum((attention-target_embedding_short)**2, dim=2))
            #print('to train', y_pred)
            return y_pred
        else:
            target = target.unsqueeze(0)
            #print('target_size', target.shape)
            #print('user_embedding', user_embedding.shape)
            user_embedding = user_embedding.unsqueeze(0).expand(target.size(1), -1)
            #print('user_embedding_after', user_embedding.shape)
            #print('attention_before', attention.shape)
            attention = attention.expand(target.size(1), -1)
            #print('attention', attention.shape)
            y_pred = self.w* torch.sqrt(torch.sum((user_embedding - target_embedding_long)**2, dim=1)) + (1-self.w)*torch.sqrt(torch.sum((attention-target_embedding_short)**2, dim=1))
            return y_pred

# %%
from interactions import Interactions
from eval_metrics import *

import argparse
import logging
from time import time
import datetime

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

# %%
def evaluation(model, train, test_set, candidate, topk=20):
    model.eval()
    num_users = train.num_users
    num_items = train.num_items
    batch_size = 500
    num_batches = int(num_users / batch_size) + 1
    user_indexes = np.arange(num_users)
    item_indexes = np.arange(num_items)
    pred_list = None
    train_matrix = train.tocsr()
    test_sequences = train.test_sequences.sequences

    for batchID in range(num_batches):
        start = batchID * batch_size
        end = start + batch_size

        if batchID == num_batches - 1:
            if start < num_users:
                end = num_users
            else:
                break

        batch_user_index = user_indexes[start:end]
        batch_test_sequences = test_sequences[batch_user_index]
        batch_test_sequences = np.atleast_2d(batch_test_sequences)
        batch_test_sequences = torch.from_numpy(batch_test_sequences).type(torch.LongTensor).to(device)
        batch_candidate = candidate[start:end]
        item_ids = torch.from_numpy(item_indexes).type(torch.LongTensor).to(device)
        #print('item_ids', item_ids)
        batch_user_ids = torch.from_numpy(np.array(batch_user_index)).type(torch.LongTensor).to(device) 
        #print('batch_user_ids', batch_user_ids)
        # get te prediction rating: for_pred = True
        rating_pred = np.empty([batch_user_ids.size(0),item_ids.size(0)])
        #print(rating_pred[.shape])
        for idx in range(batch_user_ids.size(0)):
            uid = torch.tensor([idx])
            reduct = batch_candidate[idx]
            uid_pred = model(batch_test_sequences[idx].unsqueeze(0), uid, item_ids, True)
            pred = uid_pred.cpu().detach().numpy()
            for i in range(len(reduct)):
                pred[i] = -100
            rating_pred[idx] = pred
            #print(rating_pred)
        #rating_pred = model(batch_test_sequences, batch_user_ids, item_ids, True)
        #rating_pred = rating_pred.data.numpy().copy()
        rating_pred[train_matrix[batch_user_index].toarray() > 0] = 0
        #print(rating_pred[0])
        
        # reference: https://stackoverflow.com/a/23734295, https://stackoverflow.com/a/20104162
        ind = np.argpartition(rating_pred, -topk)
        #print(ind)
        ind = ind[:, -topk:]
        arr_ind = rating_pred[np.arange(len(rating_pred))[:, None], ind]
        arr_ind_argsort = np.argsort(arr_ind)[np.arange(len(rating_pred)), ::-1]
        batch_pred_list = ind[np.arange(len(rating_pred))[:, None], arr_ind_argsort]
        #print('batch_pred_list', batch_pred_list.shape)

        if batchID == 0:
            pred_list = batch_pred_list
        else:
            pred_list = np.append(pred_list, batch_pred_list, axis=0)
    #print(pred_list.shape)
    precision, recall, MAP, ndcg = [], [], [], []
    for k in [5, 10, 15, 20]:
        precision.append(precision_at_k(test_set, pred_list, k))
        recall.append(recall_at_k(test_set, pred_list, k))
        MAP.append(mapk(test_set, pred_list, k))
        ndcg.append(ndcg_k(test_set, pred_list, k))

    return precision, recall, MAP, ndcg

# %%
def negsamp_vectorized_bsearch_preverif(pos_inds, n_items, n_samp=32):
    """ Pre-verified with binary search
    `pos_inds` is assumed to be ordered
    reference: https://tech.hbc.com/2018-03-23-negative-sampling-in-numpy.html
    """
    raw_samp = np.random.randint(0, n_items - len(pos_inds), size=n_samp)
    pos_inds_adj = pos_inds - np.arange(len(pos_inds))
    neg_inds = raw_samp + np.searchsorted(pos_inds_adj, raw_samp, side='right')
    return neg_inds


def generate_negative_samples(train_matrix, num_neg=3, num_sets=10):
    neg_samples = []
    for user_id, row in enumerate(train_matrix):
        pos_ind = row.indices
        neg_sample = negsamp_vectorized_bsearch_preverif(pos_ind, train_matrix.shape[1], num_neg * num_sets)
        neg_samples.append(neg_sample)

    return np.asarray(neg_samples).reshape(num_sets, train_matrix.shape[0], num_neg)


def train_model(model, train_data, test_data, candidate, config):
    num_users = train_data.num_users
    num_items = train_data.num_items

    # convert to sequences, targets and users
    sequences_np = train_data.sequences.sequences
    #print(sequences_np)
    targets_np = train_data.sequences.targets
    users_np = train_data.sequences.user_ids
    train_matrix = train_data.tocsr()

    n_train = sequences_np.shape[0]
    logger.info("Total training records:{}".format(n_train))

    optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate, weight_decay=config.l2)

    record_indexes = np.arange(n_train)
    batch_size = config.batch_size
    num_batches = int(n_train / batch_size) + 1
    for epoch_num in range(config.n_iter):

        t1 = time()

        # set model to training mode
        model.train()

        np.random.shuffle(record_indexes)

        t_neg_start = time()
        negatives_np_multi = generate_negative_samples(train_matrix, config.neg_samples, config.sets_of_neg_samples)
        logger.info("Negative sampling time: {}s".format(time() - t_neg_start))

        epoch_loss = 0.0
        for batchID in range(num_batches):
            start = batchID * batch_size
            end = start + batch_size

            if batchID == num_batches - 1:
                if start < n_train:
                    end = n_train
                else:
                    break

            batch_record_index = record_indexes[start:end]

            batch_users = users_np[batch_record_index]
            batch_sequences = sequences_np[batch_record_index]
            batch_targets = targets_np[batch_record_index]
            negatives_np = negatives_np_multi[batchID % config.sets_of_neg_samples]
            batch_neg = negatives_np[batch_users]

            batch_users = torch.from_numpy(batch_users).type(torch.LongTensor).to(device)
            batch_sequences = torch.from_numpy(batch_sequences).type(torch.LongTensor).to(device)
            batch_targets = torch.from_numpy(batch_targets).type(torch.LongTensor).to(device)
            batch_negatives = torch.from_numpy(batch_neg).type(torch.LongTensor).to(device)

            items_to_predict = torch.cat((batch_targets, batch_negatives), 1)
            prediction_score = model(batch_sequences, batch_users, items_to_predict, False)
            #print(prediction_score.shape)
            (targets_prediction, negatives_prediction) = torch.split(
                prediction_score, [batch_targets.size(1), batch_negatives.size(1)], dim=1)

            # compute the hinge loss
            #loss = torch.mean(F.relu(targets_prediction - negatives_prediction + 0.5), dim=1).unsqueeze(1)
            loss = -torch.log(torch.sigmoid(targets_prediction - negatives_prediction) + 1e-8)
            loss = torch.mean(torch.sum(loss))

            epoch_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # clean the grad, 
            #optimizer.zero_grad()
        epoch_loss /= num_batches

        t2 = time()

        output_str = "Epoch %d [%.1f s]  loss=%.4f" % (epoch_num + 1, t2 - t1, epoch_loss)
        logger.info(output_str)

        
        if (epoch_num + 1) % 20 == 0:
            precision, recall, MAP, ndcg = evaluation(model, train_data, test_data, candidate, topk=20)
            logger.info(', '.join(str(e) for e in precision))
            logger.info(', '.join(str(e) for e in recall))
            logger.info(', '.join(str(e) for e in MAP))
            logger.info(', '.join(str(e) for e in ndcg))
            logger.info("Evaluation time:{}".format(time() - t2))
    logger.info("\n")
    logger.info("\n")
    #torch.save(model.state_dict(), 'car.pkl')
    #print('model arg save complete')

# %%
# split train test data        
def split_data_sequentially(user_records, test_radio=0.2):
    train_set = []
    test_set = []

    for item_list in user_records:
        len_list = len(item_list)
        num_test_samples = int(math.ceil(len_list * test_radio))
        train_sample = []
        test_sample = []
        for i in range(len_list - num_test_samples, len_list):
            test_sample.append(item_list[i])
            
        for place in item_list:
            if place not in set(test_sample):
                train_sample.append(place)
                
        train_set.append(train_sample)
        test_set.append(test_sample)

    return train_set, test_set
    

def generate_dataset(seq_data):
    user_records = seq_data.tolist()
    # split dataset
    train_val_set, test_set = split_data_sequentially(user_records, test_radio=0.2)
    train_set, val_set = split_data_sequentially(train_val_set, test_radio=0.1)

    return train_set, val_set, train_val_set, test_set, 1083, 9989

# %%
train_set, val_set, train_val_set, test_set, num_users, num_items = generate_dataset(seq_data)

# %%
parser = argparse.ArgumentParser()

# data arguments
parser.add_argument('--L', type=int, default=5)
parser.add_argument('--T', type=int, default=3)
# train arguments
parser.add_argument('--n_iter', type=int, default=200)
parser.add_argument('--seed', type=int, default=1234)
parser.add_argument('--batch_size', type=int, default=4096)
parser.add_argument('--learning_rate', type=float, default=1e-3)
parser.add_argument('--l2', type=float, default=1e-3)
parser.add_argument('--neg_samples', type=int, default=3)
parser.add_argument('--sets_of_neg_samples', type=int, default=50)

# model dependent arguments
parser.add_argument('--d', type=int, default=100)
config = parser.parse_args(
    args = [
        '--L', '5',
        '--T', '3',
        '--n_iter', '200',
        '--seed', '1200',
        '--batch_size', '500',
        '--learning_rate', '0.001',
        '--l2', '0.001',
        '--neg_samples', '3',
        '--sets_of_neg_samples', '30'
    ])

# %%
train = Interactions(train_val_set, num_users, num_items)
train.to_sequence(config.L, config.T)

logger.info(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
logger.info(config)
model = selfAtt(num_users, num_items, config, device).to(device)
train_model(model, train, test_set,candidate_seq, config)
# Out:
# INFO:__main__:2021-06-16 02:21:49
# INFO:__main__:Namespace(L=5, T=3, batch_size=500, d=100, l2=0.001, learning_rate=0.001, n_iter=200, neg_samples=3, seed=1200, sets_of_neg_samples=30)
# INFO:__main__:Total training records:54872
# INFO:__main__:Negative sampling time: 0.05485391616821289s
# INFO:__main__:Epoch 1 [0.7 s]  loss=1118.6299
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 2 [0.7 s]  loss=926.2329
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 3 [0.7 s]  loss=807.1997
# INFO:__main__:Negative sampling time: 0.0558781623840332s
# INFO:__main__:Epoch 4 [0.7 s]  loss=721.6040
# INFO:__main__:Negative sampling time: 0.05436372756958008s
# INFO:__main__:Epoch 5 [0.7 s]  loss=664.0343
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 6 [0.7 s]  loss=622.1079
# INFO:__main__:Negative sampling time: 0.054856061935424805s
# INFO:__main__:Epoch 7 [0.7 s]  loss=591.9751
# INFO:__main__:Negative sampling time: 0.05485224723815918s
# INFO:__main__:Epoch 8 [0.7 s]  loss=563.3342
# INFO:__main__:Negative sampling time: 0.05385565757751465s
# INFO:__main__:Epoch 9 [0.7 s]  loss=543.3350
# INFO:__main__:Negative sampling time: 0.05585050582885742s
# INFO:__main__:Epoch 10 [0.7 s]  loss=522.5231
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 11 [0.7 s]  loss=509.9474
# INFO:__main__:Negative sampling time: 0.05385565757751465s
# INFO:__main__:Epoch 12 [0.7 s]  loss=493.2598
# INFO:__main__:Negative sampling time: 0.054852962493896484s
# INFO:__main__:Epoch 13 [0.7 s]  loss=482.6175
# INFO:__main__:Negative sampling time: 0.05585145950317383s
# INFO:__main__:Epoch 14 [0.6 s]  loss=469.8470
# INFO:__main__:Negative sampling time: 0.05432772636413574s
# INFO:__main__:Epoch 15 [0.6 s]  loss=459.7363
# INFO:__main__:Negative sampling time: 0.05482220649719238s
# INFO:__main__:Epoch 16 [0.6 s]  loss=442.7809
# INFO:__main__:Negative sampling time: 0.05485367774963379s
# INFO:__main__:Epoch 17 [0.6 s]  loss=434.8583
# INFO:__main__:Negative sampling time: 0.054880380630493164s
# INFO:__main__:Epoch 18 [0.6 s]  loss=423.4857
# INFO:__main__:Negative sampling time: 0.05482673645019531s
# INFO:__main__:Epoch 19 [0.6 s]  loss=417.0968
# INFO:__main__:Negative sampling time: 0.05485367774963379s
# INFO:__main__:Epoch 20 [0.6 s]  loss=410.7328
# INFO:__main__:0.08716528162511596, 0.05817174515235494, 0.04573714989227482, 0.03882733148661127
# INFO:__main__:0.029517092005979968, 0.038820848567823654, 0.04557340165367115, 0.05143794253518472
# INFO:__main__:0.05240073868882733, 0.029578588283574434, 0.020911237555479738, 0.01705749563906075
# INFO:__main__:0.09523166221024293, 0.07212844332374788, 0.060875185994470074, 0.0555311239849331
# INFO:__main__:Evaluation time:1.8815102577209473
# INFO:__main__:Negative sampling time: 0.054491281509399414s
# INFO:__main__:Epoch 21 [0.6 s]  loss=401.8439
# INFO:__main__:Negative sampling time: 0.05385589599609375s
# INFO:__main__:Epoch 22 [0.6 s]  loss=392.4626
# INFO:__main__:Negative sampling time: 0.05539441108703613s
# INFO:__main__:Epoch 23 [0.6 s]  loss=386.4079
# INFO:__main__:Negative sampling time: 0.05430006980895996s
# INFO:__main__:Epoch 24 [0.6 s]  loss=381.4567
# INFO:__main__:Negative sampling time: 0.05385613441467285s
# INFO:__main__:Epoch 25 [0.6 s]  loss=371.3907
# INFO:__main__:Negative sampling time: 0.05385541915893555s
# INFO:__main__:Epoch 26 [0.6 s]  loss=367.4629
# INFO:__main__:Negative sampling time: 0.05485272407531738s
# INFO:__main__:Epoch 27 [0.6 s]  loss=364.5704
# INFO:__main__:Negative sampling time: 0.05582118034362793s
# INFO:__main__:Epoch 28 [0.6 s]  loss=359.0744
# INFO:__main__:Negative sampling time: 0.054854393005371094s
# INFO:__main__:Epoch 29 [0.6 s]  loss=350.1055
# INFO:__main__:Negative sampling time: 0.05485391616821289s
# INFO:__main__:Epoch 30 [0.6 s]  loss=344.8805
# INFO:__main__:Negative sampling time: 0.05388689041137695s
# INFO:__main__:Epoch 31 [0.6 s]  loss=340.3462
# INFO:__main__:Negative sampling time: 0.05485272407531738s
# INFO:__main__:Epoch 32 [0.6 s]  loss=335.6257
# INFO:__main__:Negative sampling time: 0.053856849670410156s
# INFO:__main__:Epoch 33 [0.6 s]  loss=329.2154
# INFO:__main__:Negative sampling time: 0.05535721778869629s
# INFO:__main__:Epoch 34 [0.6 s]  loss=325.6753
# INFO:__main__:Negative sampling time: 0.05585002899169922s
# INFO:__main__:Epoch 35 [0.6 s]  loss=321.3798
# INFO:__main__:Negative sampling time: 0.05385446548461914s
# INFO:__main__:Epoch 36 [0.6 s]  loss=313.5520
# INFO:__main__:Negative sampling time: 0.054852962493896484s
# INFO:__main__:Epoch 37 [0.6 s]  loss=313.6074
# INFO:__main__:Negative sampling time: 0.05436110496520996s
# INFO:__main__:Epoch 38 [0.6 s]  loss=310.3698
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 39 [0.6 s]  loss=303.4398
# INFO:__main__:Negative sampling time: 0.05488109588623047s
# INFO:__main__:Epoch 40 [0.6 s]  loss=300.3937
# INFO:__main__:0.08384118190212425, 0.05789473684210563, 0.044690674053555174, 0.03767313019390584
# INFO:__main__:0.0280874099732653, 0.039201866070218534, 0.044572392135038254, 0.05015047961898178
# INFO:__main__:0.04863650353955063, 0.02798798897829369, 0.019746128462986397, 0.016117744272632375
# INFO:__main__:0.08960218260353404, 0.06960078344738728, 0.05831661452339448, 0.05307715093600518
# INFO:__main__:Evaluation time:1.8443500995635986
# INFO:__main__:Negative sampling time: 0.054368019104003906s
# INFO:__main__:Epoch 41 [0.6 s]  loss=296.6202
# INFO:__main__:Negative sampling time: 0.05585026741027832s
# INFO:__main__:Epoch 42 [0.6 s]  loss=291.9151
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 43 [0.6 s]  loss=288.0495
# INFO:__main__:Negative sampling time: 0.05585026741027832s
# INFO:__main__:Epoch 44 [0.6 s]  loss=286.1836
# INFO:__main__:Negative sampling time: 0.053884029388427734s
# INFO:__main__:Epoch 45 [0.6 s]  loss=281.1945
# INFO:__main__:Negative sampling time: 0.055850982666015625s
# INFO:__main__:Epoch 46 [0.6 s]  loss=277.1306
# INFO:__main__:Negative sampling time: 0.05385541915893555s
# INFO:__main__:Epoch 47 [0.6 s]  loss=272.1374
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 48 [0.6 s]  loss=272.9486
# INFO:__main__:Negative sampling time: 0.05485367774963379s
# INFO:__main__:Epoch 49 [0.6 s]  loss=266.7508
# INFO:__main__:Negative sampling time: 0.05488109588623047s
# INFO:__main__:Epoch 50 [0.6 s]  loss=263.8987
# INFO:__main__:Negative sampling time: 0.05385565757751465s
# INFO:__main__:Epoch 51 [0.6 s]  loss=262.5399
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 52 [0.7 s]  loss=258.8907
# INFO:__main__:Negative sampling time: 0.05285978317260742s
# INFO:__main__:Epoch 53 [0.6 s]  loss=253.9863
# INFO:__main__:Negative sampling time: 0.05585026741027832s
# INFO:__main__:Epoch 54 [0.6 s]  loss=251.0863
# INFO:__main__:Negative sampling time: 0.05385613441467285s
# INFO:__main__:Epoch 55 [0.6 s]  loss=251.0494
# INFO:__main__:Negative sampling time: 0.053856611251831055s
# INFO:__main__:Epoch 56 [0.6 s]  loss=246.7973
# INFO:__main__:Negative sampling time: 0.05587935447692871s
# INFO:__main__:Epoch 57 [0.7 s]  loss=244.1337
# INFO:__main__:Negative sampling time: 0.05585074424743652s
# INFO:__main__:Epoch 58 [0.6 s]  loss=243.1565
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 59 [0.7 s]  loss=237.4873
# INFO:__main__:Negative sampling time: 0.055850982666015625s
# INFO:__main__:Epoch 60 [0.6 s]  loss=235.9005
# INFO:__main__:0.08513388734995433, 0.058633425669437134, 0.04666051092643919, 0.0388734995383195
# INFO:__main__:0.02894936034500927, 0.03955426455549865, 0.04680020067068813, 0.05221353578254047
# INFO:__main__:0.0515881809787627, 0.029464963578536986, 0.020806621476058225, 0.01692944252460518
# INFO:__main__:0.09371476551139128, 0.07220288651340256, 0.06129535313513456, 0.055472241060193814
# INFO:__main__:Evaluation time:1.8913207054138184
# INFO:__main__:Negative sampling time: 0.05587887763977051s
# INFO:__main__:Epoch 61 [0.7 s]  loss=232.6139
# INFO:__main__:Negative sampling time: 0.0548858642578125s
# INFO:__main__:Epoch 62 [0.7 s]  loss=229.0885
# INFO:__main__:Negative sampling time: 0.05485391616821289s
# INFO:__main__:Epoch 63 [0.7 s]  loss=229.6405
# INFO:__main__:Negative sampling time: 0.05285906791687012s
# INFO:__main__:Epoch 64 [0.7 s]  loss=226.9524
# INFO:__main__:Negative sampling time: 0.05585050582885742s
# INFO:__main__:Epoch 65 [0.7 s]  loss=223.0457
# INFO:__main__:Negative sampling time: 0.05585002899169922s
# INFO:__main__:Epoch 66 [0.7 s]  loss=220.0372
# INFO:__main__:Negative sampling time: 0.05385589599609375s
# INFO:__main__:Epoch 67 [0.7 s]  loss=217.7098
# INFO:__main__:Negative sampling time: 0.054852962493896484s
# INFO:__main__:Epoch 68 [0.7 s]  loss=217.3905
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 69 [0.7 s]  loss=213.0157
# INFO:__main__:Negative sampling time: 0.05385565757751465s
# INFO:__main__:Epoch 70 [0.7 s]  loss=212.6885
# INFO:__main__:Negative sampling time: 0.05380535125732422s
# INFO:__main__:Epoch 71 [0.7 s]  loss=211.7400
# INFO:__main__:Negative sampling time: 0.05485391616821289s
# INFO:__main__:Epoch 72 [0.7 s]  loss=208.0942
# INFO:__main__:Negative sampling time: 0.052828311920166016s
# INFO:__main__:Epoch 73 [0.7 s]  loss=204.2689
# INFO:__main__:Negative sampling time: 0.0553584098815918s
# INFO:__main__:Epoch 74 [0.7 s]  loss=203.6757
# INFO:__main__:Negative sampling time: 0.05385637283325195s
# INFO:__main__:Epoch 75 [0.6 s]  loss=204.5016
# INFO:__main__:Negative sampling time: 0.05386614799499512s
# INFO:__main__:Epoch 76 [0.6 s]  loss=200.1882
# INFO:__main__:Negative sampling time: 0.05385446548461914s
# INFO:__main__:Epoch 77 [0.7 s]  loss=197.6861
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 78 [0.7 s]  loss=196.8595
# INFO:__main__:Negative sampling time: 0.05585289001464844s
# INFO:__main__:Epoch 79 [0.7 s]  loss=194.5062
# INFO:__main__:Negative sampling time: 0.05485272407531738s
# INFO:__main__:Epoch 80 [0.6 s]  loss=195.3548
# INFO:__main__:0.07996306555863392, 0.05909510618651931, 0.04653739612188399, 0.03984302862419206
# INFO:__main__:0.027022670676201434, 0.040005667909665296, 0.046832191367720634, 0.0532957918031845
# INFO:__main__:0.0500492459218221, 0.02914175057526858, 0.020588338102023627, 0.01690620704509498
# INFO:__main__:0.09037975928724853, 0.07224936511435963, 0.06107571163099844, 0.05607362149059686
# INFO:__main__:Evaluation time:1.8994510173797607
# INFO:__main__:Negative sampling time: 0.053854942321777344s
# INFO:__main__:Epoch 81 [0.6 s]  loss=192.3823
# INFO:__main__:Negative sampling time: 0.05385446548461914s
# INFO:__main__:Epoch 82 [0.6 s]  loss=190.3081
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 83 [0.7 s]  loss=190.2834
# INFO:__main__:Negative sampling time: 0.05385541915893555s
# INFO:__main__:Epoch 84 [0.7 s]  loss=187.0818
# INFO:__main__:Negative sampling time: 0.05582284927368164s
# INFO:__main__:Epoch 85 [0.7 s]  loss=185.4552
# INFO:__main__:Negative sampling time: 0.05285763740539551s
# INFO:__main__:Epoch 86 [0.7 s]  loss=184.6844
# INFO:__main__:Negative sampling time: 0.05485272407531738s
# INFO:__main__:Epoch 87 [0.7 s]  loss=183.0294
# INFO:__main__:Negative sampling time: 0.05285978317260742s
# INFO:__main__:Epoch 88 [0.6 s]  loss=180.1269
# INFO:__main__:Negative sampling time: 0.05485415458679199s
# INFO:__main__:Epoch 89 [0.6 s]  loss=181.1352
# INFO:__main__:Negative sampling time: 0.05385565757751465s
# INFO:__main__:Epoch 90 [0.7 s]  loss=179.8946
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 91 [0.7 s]  loss=179.1793
# INFO:__main__:Negative sampling time: 0.053854942321777344s
# INFO:__main__:Epoch 92 [0.7 s]  loss=176.7194
# INFO:__main__:Negative sampling time: 0.0558781623840332s
# INFO:__main__:Epoch 93 [0.6 s]  loss=175.7983
# INFO:__main__:Negative sampling time: 0.053854942321777344s
# INFO:__main__:Epoch 94 [0.6 s]  loss=174.2325
# INFO:__main__:Negative sampling time: 0.05385637283325195s
# INFO:__main__:Epoch 95 [0.6 s]  loss=171.8838
# INFO:__main__:Negative sampling time: 0.054852962493896484s
# INFO:__main__:Epoch 96 [0.6 s]  loss=173.6536
# INFO:__main__:Negative sampling time: 0.05385851860046387s
# INFO:__main__:Epoch 97 [0.6 s]  loss=171.4495
# INFO:__main__:Negative sampling time: 0.05385541915893555s
# INFO:__main__:Epoch 98 [0.6 s]  loss=171.9818
# INFO:__main__:Negative sampling time: 0.054883718490600586s
# INFO:__main__:Epoch 99 [0.6 s]  loss=170.1309
# INFO:__main__:Negative sampling time: 0.05536317825317383s
# INFO:__main__:Epoch 100 [0.6 s]  loss=170.1695
# INFO:__main__:0.08531855955678723, 0.06038781163434941, 0.047583871960603576, 0.04067405355493997
# INFO:__main__:0.029306475454322908, 0.04053965233456397, 0.047719087593328734, 0.05431510051092415
# INFO:__main__:0.05236072637734687, 0.03005620777088921, 0.021234138064371542, 0.017421684032275165
# INFO:__main__:0.09461737942593441, 0.0739190647020018, 0.06249113925237438, 0.057307086761660776
# INFO:__main__:Evaluation time:1.902942180633545
# INFO:__main__:Negative sampling time: 0.05386614799499512s
# INFO:__main__:Epoch 101 [0.6 s]  loss=169.7560
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 102 [0.6 s]  loss=166.0779
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 103 [0.6 s]  loss=167.4007
# INFO:__main__:Negative sampling time: 0.052857398986816406s
# INFO:__main__:Epoch 104 [0.6 s]  loss=166.1672
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 105 [0.6 s]  loss=165.4573
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 106 [0.6 s]  loss=163.6461
# INFO:__main__:Negative sampling time: 0.05485391616821289s
# INFO:__main__:Epoch 107 [0.6 s]  loss=163.5085
# INFO:__main__:Negative sampling time: 0.05485200881958008s
# INFO:__main__:Epoch 108 [0.6 s]  loss=161.5952
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 109 [0.6 s]  loss=161.9869
# INFO:__main__:Negative sampling time: 0.05388307571411133s
# INFO:__main__:Epoch 110 [0.6 s]  loss=162.0378
# INFO:__main__:Negative sampling time: 0.05385923385620117s
# INFO:__main__:Epoch 111 [0.6 s]  loss=160.3086
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 112 [0.6 s]  loss=159.6552
# INFO:__main__:Negative sampling time: 0.053855180740356445s
# INFO:__main__:Epoch 113 [0.6 s]  loss=159.5749
# INFO:__main__:Negative sampling time: 0.05585026741027832s
# INFO:__main__:Epoch 114 [0.6 s]  loss=158.4481
# INFO:__main__:Negative sampling time: 0.05385637283325195s
# INFO:__main__:Epoch 115 [0.6 s]  loss=157.8277
# INFO:__main__:Negative sampling time: 0.05385613441467285s
# INFO:__main__:Epoch 116 [0.6 s]  loss=158.5182
# INFO:__main__:Negative sampling time: 0.05485367774963379s
# INFO:__main__:Epoch 117 [0.7 s]  loss=158.3899
# INFO:__main__:Negative sampling time: 0.05585026741027832s
# INFO:__main__:Epoch 118 [0.7 s]  loss=157.0485
# INFO:__main__:Negative sampling time: 0.055822134017944336s
# INFO:__main__:Epoch 119 [0.7 s]  loss=157.9977
# INFO:__main__:Negative sampling time: 0.05385851860046387s
# INFO:__main__:Epoch 120 [0.7 s]  loss=154.7664
# INFO:__main__:0.08199445983379552, 0.06066481994459871, 0.048691905201600834, 0.04201292705447829
# INFO:__main__:0.027857720635559004, 0.04059839594085406, 0.049038478543962365, 0.05625484471090289
# INFO:__main__:0.04986149584487535, 0.029338001436339387, 0.020895463257618645, 0.01717621742803948
# INFO:__main__:0.09064135986408842, 0.07279927214469453, 0.06229387157906231, 0.057468712990009885
# INFO:__main__:Evaluation time:2.047621250152588
# INFO:__main__:Negative sampling time: 0.05585050582885742s
# INFO:__main__:Epoch 121 [0.7 s]  loss=153.5153
# INFO:__main__:Negative sampling time: 0.05485391616821289s
# INFO:__main__:Epoch 122 [0.6 s]  loss=155.1662
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 123 [0.7 s]  loss=154.7098
# INFO:__main__:Negative sampling time: 0.05385589599609375s
# INFO:__main__:Epoch 124 [0.7 s]  loss=155.3340
# INFO:__main__:Negative sampling time: 0.05591893196105957s
# INFO:__main__:Epoch 125 [0.6 s]  loss=153.5681
# INFO:__main__:Negative sampling time: 0.0548551082611084s
# INFO:__main__:Epoch 126 [0.6 s]  loss=152.8879
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 127 [0.7 s]  loss=154.7774
# INFO:__main__:Negative sampling time: 0.05436992645263672s
# INFO:__main__:Epoch 128 [0.6 s]  loss=153.0420
# INFO:__main__:Negative sampling time: 0.05536174774169922s
# INFO:__main__:Epoch 129 [0.6 s]  loss=154.1188
# INFO:__main__:Negative sampling time: 0.05385470390319824s
# INFO:__main__:Epoch 130 [0.6 s]  loss=150.8436
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 131 [0.6 s]  loss=149.8767
# INFO:__main__:Negative sampling time: 0.055947303771972656s
# INFO:__main__:Epoch 132 [0.6 s]  loss=150.5773
# INFO:__main__:Negative sampling time: 0.05585169792175293s
# INFO:__main__:Epoch 133 [0.7 s]  loss=150.4635
# INFO:__main__:Negative sampling time: 0.05385899543762207s
# INFO:__main__:Epoch 134 [0.7 s]  loss=150.8943
# INFO:__main__:Negative sampling time: 0.05385541915893555s
# INFO:__main__:Epoch 135 [0.6 s]  loss=150.5533
# INFO:__main__:Negative sampling time: 0.055852651596069336s
# INFO:__main__:Epoch 136 [0.6 s]  loss=149.6476
# INFO:__main__:Negative sampling time: 0.05585050582885742s
# INFO:__main__:Epoch 137 [0.7 s]  loss=149.4741
# INFO:__main__:Negative sampling time: 0.05485367774963379s
# INFO:__main__:Epoch 138 [0.7 s]  loss=149.5698
# INFO:__main__:Negative sampling time: 0.05585193634033203s
# INFO:__main__:Epoch 139 [0.7 s]  loss=148.7572
# INFO:__main__:Negative sampling time: 0.055823326110839844s
# INFO:__main__:Epoch 140 [0.7 s]  loss=147.6034
# INFO:__main__:0.08162511542012976, 0.06029547553093296, 0.048507232994767946, 0.04127423822714682
# INFO:__main__:0.02765369241969188, 0.040641157163068015, 0.0489124942583699, 0.05470108721054872
# INFO:__main__:0.050323176361957524, 0.029447302466693054, 0.02096909553973266, 0.01727517052581572
# INFO:__main__:0.09183558384294778, 0.07340324559558753, 0.06278187441627478, 0.05745219117960301
# INFO:__main__:Evaluation time:1.916417121887207
# INFO:__main__:Negative sampling time: 0.05485272407531738s
# INFO:__main__:Epoch 141 [0.7 s]  loss=147.1318
# INFO:__main__:Negative sampling time: 0.05333542823791504s
# INFO:__main__:Epoch 142 [0.6 s]  loss=148.4358
# INFO:__main__:Negative sampling time: 0.05385541915893555s
# INFO:__main__:Epoch 143 [0.6 s]  loss=147.3044
# INFO:__main__:Negative sampling time: 0.05485391616821289s
# INFO:__main__:Epoch 144 [0.6 s]  loss=147.1334
# INFO:__main__:Negative sampling time: 0.05585026741027832s
# INFO:__main__:Epoch 145 [0.6 s]  loss=147.5365
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 146 [0.6 s]  loss=144.5518
# INFO:__main__:Negative sampling time: 0.05585002899169922s
# INFO:__main__:Epoch 147 [0.6 s]  loss=147.7348
# INFO:__main__:Negative sampling time: 0.05382966995239258s
# INFO:__main__:Epoch 148 [0.6 s]  loss=145.3071
# INFO:__main__:Negative sampling time: 0.0553586483001709s
# INFO:__main__:Epoch 149 [0.6 s]  loss=144.9891
# INFO:__main__:Negative sampling time: 0.05485248565673828s
# INFO:__main__:Epoch 150 [0.6 s]  loss=146.1936
# INFO:__main__:Negative sampling time: 0.054880619049072266s
# INFO:__main__:Epoch 151 [0.6 s]  loss=145.1706
# INFO:__main__:Negative sampling time: 0.05385613441467285s
# INFO:__main__:Epoch 152 [0.6 s]  loss=145.7862
# INFO:__main__:Negative sampling time: 0.05385565757751465s
# INFO:__main__:Epoch 153 [0.6 s]  loss=145.5520
# INFO:__main__:Negative sampling time: 0.05485200881958008s
# INFO:__main__:Epoch 154 [0.6 s]  loss=144.9064
# INFO:__main__:Negative sampling time: 0.05458235740661621s
# INFO:__main__:Epoch 155 [0.6 s]  loss=143.7159
# INFO:__main__:Negative sampling time: 0.05485415458679199s
# INFO:__main__:Epoch 156 [0.7 s]  loss=144.1526
# INFO:__main__:Negative sampling time: 0.05684685707092285s
# INFO:__main__:Epoch 157 [0.7 s]  loss=144.1008
# INFO:__main__:Negative sampling time: 0.055849313735961914s
# INFO:__main__:Epoch 158 [0.7 s]  loss=143.8382
# INFO:__main__:Negative sampling time: 0.055852651596069336s
# INFO:__main__:Epoch 159 [0.7 s]  loss=143.1853
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 160 [0.7 s]  loss=144.0912
# INFO:__main__:0.08550323176362012, 0.06112650046168086, 0.04930747922437708, 0.042336103416435816
# INFO:__main__:0.028981166750730935, 0.04124271572285555, 0.04923599948986899, 0.05637743226991686
# INFO:__main__:0.05267774699907664, 0.030658187867329142, 0.02185921882960532, 0.017950677664156357
# INFO:__main__:0.09621813288617748, 0.075546271571264, 0.06460407218780083, 0.059404525427285984
# INFO:__main__:Evaluation time:1.9352939128875732
# INFO:__main__:Negative sampling time: 0.055850982666015625s
# INFO:__main__:Epoch 161 [0.7 s]  loss=144.9147
# INFO:__main__:Negative sampling time: 0.05635523796081543s
# INFO:__main__:Epoch 162 [0.7 s]  loss=144.3212
# INFO:__main__:Negative sampling time: 0.055823326110839844s
# INFO:__main__:Epoch 163 [0.6 s]  loss=142.7256
# INFO:__main__:Negative sampling time: 0.05385446548461914s
# INFO:__main__:Epoch 164 [0.7 s]  loss=141.8664
# INFO:__main__:Negative sampling time: 0.05485367774963379s
# INFO:__main__:Epoch 165 [0.7 s]  loss=141.8911
# INFO:__main__:Negative sampling time: 0.05285835266113281s
# INFO:__main__:Epoch 166 [0.6 s]  loss=142.9812
# INFO:__main__:Negative sampling time: 0.0553584098815918s
# INFO:__main__:Epoch 167 [0.7 s]  loss=141.2587
# INFO:__main__:Negative sampling time: 0.05385446548461914s
# INFO:__main__:Epoch 168 [0.6 s]  loss=141.3204
# INFO:__main__:Negative sampling time: 0.055193185806274414s
# INFO:__main__:Epoch 169 [0.6 s]  loss=141.7083
# INFO:__main__:Negative sampling time: 0.053852081298828125s
# INFO:__main__:Epoch 170 [0.6 s]  loss=140.7817
# INFO:__main__:Negative sampling time: 0.05485272407531738s
# INFO:__main__:Epoch 171 [0.7 s]  loss=140.6419
# INFO:__main__:Negative sampling time: 0.05485248565673828s
# INFO:__main__:Epoch 172 [0.6 s]  loss=140.7933
# INFO:__main__:Negative sampling time: 0.05585026741027832s
# INFO:__main__:Epoch 173 [0.6 s]  loss=141.9415
# INFO:__main__:Negative sampling time: 0.05588102340698242s
# INFO:__main__:Epoch 174 [0.6 s]  loss=140.9492
# INFO:__main__:Negative sampling time: 0.05485272407531738s
# INFO:__main__:Epoch 175 [0.7 s]  loss=140.3224
# INFO:__main__:Negative sampling time: 0.05684709548950195s
# INFO:__main__:Epoch 176 [0.7 s]  loss=141.0873
# INFO:__main__:Negative sampling time: 0.05385541915893555s
# INFO:__main__:Epoch 177 [0.6 s]  loss=140.5901
# INFO:__main__:Negative sampling time: 0.054851531982421875s
# INFO:__main__:Epoch 178 [0.6 s]  loss=140.5199
# INFO:__main__:Negative sampling time: 0.05485272407531738s
# INFO:__main__:Epoch 179 [0.6 s]  loss=138.3628
# INFO:__main__:Negative sampling time: 0.054852962493896484s
# INFO:__main__:Epoch 180 [0.6 s]  loss=139.2518
# INFO:__main__:0.0877192982456146, 0.0617728531855959, 0.04998461064943095, 0.04353647276084945
# INFO:__main__:0.029567244148892908, 0.04184650822064804, 0.050116992623846356, 0.05766922376859436
# INFO:__main__:0.05392120652508464, 0.030989942367289244, 0.02215257807978645, 0.018263121029383614
# INFO:__main__:0.0980509693895621, 0.07634624228085263, 0.0653892004633373, 0.06045832424605747
# INFO:__main__:Evaluation time:1.8936841487884521
# INFO:__main__:Negative sampling time: 0.05486464500427246s
# INFO:__main__:Epoch 181 [0.7 s]  loss=140.0079
# INFO:__main__:Negative sampling time: 0.05585050582885742s
# INFO:__main__:Epoch 182 [0.6 s]  loss=139.7836
# INFO:__main__:Negative sampling time: 0.05584979057312012s
# INFO:__main__:Epoch 183 [0.6 s]  loss=139.5889
# INFO:__main__:Negative sampling time: 0.055762290954589844s
# INFO:__main__:Epoch 184 [0.6 s]  loss=140.6925
# INFO:__main__:Negative sampling time: 0.05585002899169922s
# INFO:__main__:Epoch 185 [0.6 s]  loss=137.9546
# INFO:__main__:Negative sampling time: 0.052858591079711914s
# INFO:__main__:Epoch 186 [0.6 s]  loss=138.3312
# INFO:__main__:Negative sampling time: 0.05285835266113281s
# INFO:__main__:Epoch 187 [0.6 s]  loss=139.3609
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 188 [0.6 s]  loss=138.9318
# INFO:__main__:Negative sampling time: 0.05385541915893555s
# INFO:__main__:Epoch 189 [0.6 s]  loss=137.8737
# INFO:__main__:Negative sampling time: 0.05385565757751465s
# INFO:__main__:Epoch 190 [0.6 s]  loss=138.2190
# INFO:__main__:Negative sampling time: 0.054856061935424805s
# INFO:__main__:Epoch 191 [0.7 s]  loss=137.3936
# INFO:__main__:Negative sampling time: 0.05385565757751465s
# INFO:__main__:Epoch 192 [0.7 s]  loss=139.5340
# INFO:__main__:Negative sampling time: 0.05585074424743652s
# INFO:__main__:Epoch 193 [0.6 s]  loss=138.4223
# INFO:__main__:Negative sampling time: 0.05585145950317383s
# INFO:__main__:Epoch 194 [0.6 s]  loss=139.2687
# INFO:__main__:Negative sampling time: 0.05585050582885742s
# INFO:__main__:Epoch 195 [0.6 s]  loss=137.2461
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 196 [0.6 s]  loss=138.1275
# INFO:__main__:Negative sampling time: 0.054853200912475586s
# INFO:__main__:Epoch 197 [0.6 s]  loss=136.9936
# INFO:__main__:Negative sampling time: 0.05585074424743652s
# INFO:__main__:Epoch 198 [0.6 s]  loss=139.0803
# INFO:__main__:Negative sampling time: 0.055850982666015625s
# INFO:__main__:Epoch 199 [0.7 s]  loss=137.6519
# INFO:__main__:Negative sampling time: 0.05485343933105469s
# INFO:__main__:Epoch 200 [0.7 s]  loss=137.3520
# INFO:__main__:0.08661126500461737, 0.06334256694367531, 0.04998461064943094, 0.044090489381348054
# INFO:__main__:0.02958418704771804, 0.0429128435879658, 0.05012370474661961, 0.05849005233594633
# INFO:__main__:0.05326869806094183, 0.03122290375060459, 0.022180694434608572, 0.018389591388617798
# INFO:__main__:0.0970733902198779, 0.07721010959313482, 0.06541386684289249, 0.06102526260669966
# INFO:__main__:Evaluation time:1.9536826610565186
# INFO:__main__:
#
# INFO:__main__:

# %%
r = np.zeros([3,3])

# %%
b = np.array([[1,2,3],[1,3],[1,4,2]])

# %%
np.append(r[0],b[0])

# %%
b[0]
